# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\4005\Downloads\sosang\sosangin.csv')
# Out:
# C:\Users\4005\AppData\Local\Temp\ipykernel_19544\3973733574.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\4005\Downloads\sosang\sosangin.csv')

# %%
df
# Out:
#                       상가업소번호             상호명  지점명 상권업종대분류코드 상권업종대분류명  \
# 0       MA0101202210A0089715       날으는뚝배기원창점  NaN        I2       음식
# 1       MA010120220805430815           아기숟가락  NaN        I2       음식
# 2       MA010120220805430978           러블리헤어  NaN        S2    수리·개인
# 3       MA010120220805430761             쉐프윤  NaN        I2       음식
# 4       MA010120220805430901  The선재로59Street  NaN        I1       숙박
# ...                      ...             ...  ...       ...      ...
# 113656  MA0101202307A0013333           상큼한과일  NaN        G2       소매
# 113657  MA0101202307A0023409              힐링  NaN        G2       소매
# 113658  MA0101202307A0106428           석남마사지  NaN        S2    수리·개인
# 113659  MA0101202307A0024831          아수라떡볶이  NaN        I2       음식
# 113660  MA0101202307A0045892            정석갈비  NaN        I2       음식
#
#        상권업종중분류코드   상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...  \
# 0           I201         한식    I20102    국/탕/찌개류   I56111  ...
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df.head()
# Out:
#                  상가업소번호             상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA0101202210A0089715       날으는뚝배기원창점  NaN        I2       음식      I201
# 1  MA010120220805430815           아기숟가락  NaN        I2       음식      I201
# 2  MA010120220805430978           러블리헤어  NaN        S2    수리·개인      S207
# 3  MA010120220805430761             쉐프윤  NaN        I2       음식      I210
# 4  MA010120220805430901  The선재로59Street  NaN        I1       숙박      I101
#
#   상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0       한식    I20102  국/탕/찌개류   I56111  ...  2826011100103810048000001
# 1       한식    I20105   국수/칼국수   I56194  ...  2818510600100830000000001
# 2    이용·미용    S20701      미용실   S96112  ...  2820010200106170024006353
# 3    기타 간이    I21003       피자   I56192  ...  2817010100100450003125288
# 4    일반 숙박    I10104   캠핑/글램핑   I55109  ...  2872036023101500000000001
#
#              건물명                 도로명주소   구우편번호  신우편번호  동정보  층정보  호정보  \
# ...

# %%
df[['상권업종대분류명','상권업종중분류명','상권업종소분류명']]
# Out:
#        상권업종대분류명   상권업종중분류명   상권업종소분류명
# 0            음식         한식    국/탕/찌개류
# 1            음식         한식     국수/칼국수
# 2         수리·개인      이용·미용        미용실
# 3            음식      기타 간이         피자
# 4            숙박      일반 숙박     캠핑/글램핑
# ...         ...        ...        ...
# 113656       소매     식료품 소매  채소/과일 소매업
# 113657       소매  의약·화장품 소매    화장품 소매업
# 113658    수리·개인    욕탕·신체관리   체형/비만 관리
# 113659       음식      기타 간이   김밥/만두/분식
# 113660       음식         한식  돼지고기 구이/찜
#
# [113661 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113661 entries, 0 to 113660
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     113661 non-null  object
#  1   상호명        113661 non-null  object
#  2   지점명        1772 non-null    object
#  3   상권업종대분류코드  113661 non-null  object
#  4   상권업종대분류명   113661 non-null  object
#  5   상권업종중분류코드  113661 non-null  object
#  6   상권업종중분류명   113661 non-null  object
#  7   상권업종소분류코드  113661 non-null  object
#  8   상권업종소분류명   113661 non-null  object
#  9   표준산업분류코드   113651 non-null  object
#  10  표준산업분류명    113651 non-null  object
#  11  시도코드       113661 non-null  int64
#  12  시도명        113661 non-null  object
#  13  시군구코드      113661 non-null  int64
#  14  시군구명       113661 non-null  object
#  15  행정동코드      113661 non-null  int64
#  16  행정동명       113661 non-null  object
#  17  법정동코드      113661 non-null  int64
#  18  법정동명       113661 non-null  object
# ...

# %%
null_sum = df.isnull().sum()

# %%
null_df = null_sum.reset_index

# %%
df.groupby('상권업종대분류명')['상권업종중분류명'].count().sort_values(ascending=False)
# Out:
# 상권업종대분류명
# 음식         38500
# 소매         27795
# 수리·개인      14060
# 과학·기술       9155
# 예술·스포츠      6294
# 부동산         5244
# 교육          4618
# 시설관리·임대     4073
# 숙박          2672
# 보건의료        1250
# Name: 상권업종중분류명, dtype: int64

# %%
category_a = set(df['상권업종대분류명'])
category_a, len(category_a) # 대분류 총 10가지
# Out:
# ({'과학·기술',
#   '교육',
#   '보건의료',
#   '부동산',
#   '소매',
#   '수리·개인',
#   '숙박',
#   '시설관리·임대',
#   '예술·스포츠',
#   '음식'},
#  10)

# %%
category_b = set(df['상권업종중분류명'])
category_b, len(category_b) # 중분류 총 75가지
# Out:
# ({'가구 소매',
#   '가전·통신 소매',
#   '가전제품 수리',
#   '가정용품 대여',
#   '고용 알선',
#   '광고',
#   '교육 지원',
#   '구내식당·뷔페',
#   '기술 서비스',
#   '기타 가정용품 수리',
#   '기타 간이',
#   '기타 개인',
#   '기타 교육',
#   '기타 보건',
#   '기타 사업 서비스',
#   '기타 상품 소매',
#   '기타 생활용품 소매',
#   '기타 숙박',
#   '기타 외국',
#   '기타 전문 과학',
#   '담배 소매',
#   '도서관·사적지',
#   '동남아시아',
#   '모터사이클 소매',
#   '모터사이클 수리',
#   '법무관련 ',
#   '병원',
#   '본사·경영 컨설팅',
#   '부동산 서비스',
#   '비알코올 ',
#   '사무 지원',
#   '사진 촬영',
#   '산업용품 대여',
#   '서양식',
#   '섬유·의복·신발 소매',
#   '세탁',
#   '수의',
#   '스포츠 서비스',
#   '시계·귀금속 소매',
#   '시설관리',
#   '시장 조사',
#   '식료품 소매',
#   '식물 소매',
#   '안경·정밀기기 소매',
#   '애완동물·용품 소매',
#   '여행사·보조',
#   '연료 소매',
#   '오락용품 소매',
#   '욕탕·신체관리',
#   '운송장비 대여',
#   '유원지·오락',
#   '음료 소매',
#   '의약·화장품 소매',
#   '의원',
#   '이용·미용',
#   '인쇄·제품제작',
#   '일반 교육',
#   '일반 숙박',
#   '일식',
#   '자동차 부품 소매',
#   '자동차 수리·세차',
#   '장례식장 ',
#   '장식품 소매',
#   '전문 디자인',
#   '조경·유지',
#   '종합 소매',
#   '주점',
#   '중고 상품 소매',
#   '중식',
#   '철물·건설자재 소매',
#   '청소·방제',
# ...

# %%
pd.options.display.max_columns = len(df.columns)

# %%
df
# Out:
#                       상가업소번호             상호명  지점명 상권업종대분류코드 상권업종대분류명  \
# 0       MA0101202210A0089715       날으는뚝배기원창점  NaN        I2       음식
# 1       MA010120220805430815           아기숟가락  NaN        I2       음식
# 2       MA010120220805430978           러블리헤어  NaN        S2    수리·개인
# 3       MA010120220805430761             쉐프윤  NaN        I2       음식
# 4       MA010120220805430901  The선재로59Street  NaN        I1       숙박
# ...                      ...             ...  ...       ...      ...
# 113656  MA0101202307A0013333           상큼한과일  NaN        G2       소매
# 113657  MA0101202307A0023409              힐링  NaN        G2       소매
# 113658  MA0101202307A0106428           석남마사지  NaN        S2    수리·개인
# 113659  MA0101202307A0024831          아수라떡볶이  NaN        I2       음식
# 113660  MA0101202307A0045892            정석갈비  NaN        I2       음식
#
#        상권업종중분류코드   상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  \
# 0           I201         한식    I20102    국/탕/찌개류   I56111
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df = df[['상호명','상권업종대분류명','상권업종중분류명','상권업종소분류명','지번주소','건물명']]

# %%
df
# Out:
#                    상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명                   지번주소  \
# 0            날으는뚝배기원창점       음식         한식    국/탕/찌개류    인천광역시 서구 원창동 381-48
# 1                아기숟가락       음식         한식     국수/칼국수       인천광역시 연수구 송도동 83
# 2                러블리헤어    수리·개인      이용·미용        미용실   인천광역시 남동구 간석동 617-24
# 3                  쉐프윤       음식      기타 간이         피자    인천광역시 미추홀구 숭의동 45-3
# 4       The선재로59Street       숙박      일반 숙박     캠핑/글램핑  인천광역시 옹진군 영흥면 선재리 150
# ...                ...      ...        ...        ...                    ...
# 113656           상큼한과일       소매     식료품 소매  채소/과일 소매업   인천광역시 미추홀구 숭의동 53-18
# 113657              힐링       소매  의약·화장품 소매    화장품 소매업   인천광역시 계양구 계산동 1063-4
# 113658           석남마사지    수리·개인    욕탕·신체관리   체형/비만 관리    인천광역시 서구 석남동 591-13
# 113659          아수라떡볶이       음식      기타 간이   김밥/만두/분식    인천광역시 미추홀구 도화동 94-1
# 113660            정석갈비       음식         한식  돼지고기 구이/찜    인천광역시 서구 당하동 1081-2
#
#                   건물명
# ...

# %%
df.isna().sum() # 건물명 결측치 개수 확인
# Out:
# 상호명             0
# 상권업종대분류명        0
# 상권업종중분류명        0
# 상권업종소분류명        0
# 지번주소            0
# 건물명         63570
# dtype: int64

# %%
df.isnull().sum()
# Out:
# 상호명             0
# 상권업종대분류명        0
# 상권업종중분류명        0
# 상권업종소분류명        0
# 지번주소            0
# 건물명         63570
# dtype: int64

# %%
df = df.fillna('') # NaN 값을 '' 로 대체

# %%
df
# Out:
#                    상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명                   지번주소  \
# 0            날으는뚝배기원창점       음식         한식    국/탕/찌개류    인천광역시 서구 원창동 381-48
# 1                아기숟가락       음식         한식     국수/칼국수       인천광역시 연수구 송도동 83
# 2                러블리헤어    수리·개인      이용·미용        미용실   인천광역시 남동구 간석동 617-24
# 3                  쉐프윤       음식      기타 간이         피자    인천광역시 미추홀구 숭의동 45-3
# 4       The선재로59Street       숙박      일반 숙박     캠핑/글램핑  인천광역시 옹진군 영흥면 선재리 150
# ...                ...      ...        ...        ...                    ...
# 113656           상큼한과일       소매     식료품 소매  채소/과일 소매업   인천광역시 미추홀구 숭의동 53-18
# 113657              힐링       소매  의약·화장품 소매    화장품 소매업   인천광역시 계양구 계산동 1063-4
# 113658           석남마사지    수리·개인    욕탕·신체관리   체형/비만 관리    인천광역시 서구 석남동 591-13
# 113659          아수라떡볶이       음식      기타 간이   김밥/만두/분식    인천광역시 미추홀구 도화동 94-1
# 113660            정석갈비       음식         한식  돼지고기 구이/찜    인천광역시 서구 당하동 1081-2
#
#                   건물명
# ...

# %%
df_food = df[df['상권업종대분류명'] == '음식']

# %%
df_food
# Out:
#                  상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명                   지번주소  \
# 0          날으는뚝배기원창점       음식       한식    국/탕/찌개류    인천광역시 서구 원창동 381-48
# 1              아기숟가락       음식       한식     국수/칼국수       인천광역시 연수구 송도동 83
# 3                쉐프윤       음식    기타 간이         피자    인천광역시 미추홀구 숭의동 45-3
# 6              불리다푸드       음식       한식     백반/한정식    인천광역시 남동구 논현동 665-4
# 11              우리식당       음식    기타 간이   김밥/만두/분식   인천광역시 미추홀구 도화동 88-27
# ...              ...      ...      ...        ...                    ...
# 113647       럭셔리노래클럽       음식       주점   일반 유흥 주점  인천광역시 부평구 부평동 546-143
# 113650  공화춘삼성바이오로직스점       음식       중식        중국집    인천광역시 연수구 송도동 201-2
# 113654         제주밤바다       음식       한식     백반/한정식   인천광역시 남동구 구월동 1369-2
# 113659        아수라떡볶이       음식    기타 간이   김밥/만두/분식    인천광역시 미추홀구 도화동 94-1
# 113660          정석갈비       음식       한식  돼지고기 구이/찜    인천광역시 서구 당하동 1081-2
#
#                   건물명
# 0               건원프라자
# 1       송도센트럴파크푸르지오시티
# 3
# 6
# ...

# %%
df_korea=df[df['상권업종중분류명'] == '한식']
df_china=df[df['상권업종중분류명'] == '중식']
df_japan=df[df['상권업종중분류명'] == '일식']

# %%
df_korea = df_korea.reset_index()
df_japan = df_japan.reset_index()
df_china = df_china.reset_index()

# %%
df_korea = df_korea.drop('index', axis=1)
df_japan = df_japan.drop('index', axis=1)
df_china = df_china.drop('index', axis=1)

# %%
df_korea
# Out:
#              상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명                  지번주소  \
# 0      날으는뚝배기원창점       음식       한식    국/탕/찌개류   인천광역시 서구 원창동 381-48
# 1          아기숟가락       음식       한식     국수/칼국수      인천광역시 연수구 송도동 83
# 2          불리다푸드       음식       한식     백반/한정식   인천광역시 남동구 논현동 665-4
# 3        건강밥상심마니       음식       한식     백반/한정식    인천광역시 연수구 송도동 22-5
# 4            돈사미       음식       한식  돼지고기 구이/찜    인천광역시 서구 검암동 627-2
# ...          ...      ...      ...        ...                   ...
# 15312        돼로변       음식       한식     백반/한정식   인천광역시 중구 운서동 3093-8
# 15313       정성밥상       음식       한식     백반/한정식    인천광역시 계양구 임학동 71-7
# 15314      송도주물럭       음식       한식  돼지고기 구이/찜   인천광역시 연수구 송도동 21-60
# 15315      제주밤바다       음식       한식     백반/한정식  인천광역시 남동구 구월동 1369-2
# 15316       정석갈비       음식       한식  돼지고기 구이/찜   인천광역시 서구 당하동 1081-2
#
#                  건물명
# 0              건원프라자
# 1      송도센트럴파크푸르지오시티
# 2
# 3              세종프라자
# 4
# ...              ...
# 15312        수린나오피스텔
# 15313
# ...

# %%
set(df_china['상권업종소분류명'])
# Out:
# {'마라탕/훠궈', '중국집'}

# %%
set(df_korea['상권업종소분류명'])
# Out:
# {'곱창 전골/구이',
#  '국/탕/찌개류',
#  '국수/칼국수',
#  '기타 한식 음식점',
#  '냉면/밀면',
#  '닭/오리고기 구이/찜',
#  '돼지고기 구이/찜',
#  '백반/한정식',
#  '복 요리 전문',
#  '소고기 구이/찜',
#  '전/부침개',
#  '족발/보쌈',
#  '해산물 구이/찜',
#  '횟집'}

# %%
set(df_japan['상권업종소분류명'])
# Out:
# {'기타 일식 음식점', '일식 면 요리', '일식 카레/돈가스/덮밥', '일식 회/초밥'}

# %%
df_china[df['상권업종소분류명'] == '중국집']
# Out:
# C:\Users\4005\AppData\Local\Temp\ipykernel_19544\1698427342.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_china[df['상권업종소분류명'] == '중국집']
#                상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명                     지번주소  \
# 175         동춘동양꼬치       음식       중식      중국집      인천광역시 연수구 동춘동 936-6
# 239   중국전통마라탕.마라향궈       음식       중식      중국집      인천광역시 중구 운서동 3109-3
# 266         마수리마라탕       음식       중식   마라탕/훠궈       인천광역시 서구 심곡동 298-4
# 409        짜미옥중화요리       음식       중식      중국집      인천광역시 서구 당하동 1033-3
# 417            중국관       음식       중식      중국집     인천광역시 부평구 산곡동 263-15
# 751       태양푸드목향지점       음식       중식      중국집     인천광역시 연수구 송도동 10-110
# 802            이화원       음식       중식      중국집  인천광역시 옹진군 백령면 진촌리 744-1
# 929            사오성       음식       중식      중국집    인천광역시 부평구 산곡동 370-399
# 964           중화명가       음식       중식      중국집     인천광역시 부평구 부개동 131-14
# 979    팔진향한옥엔타스에스디       음식       중식      중국집      인천광역시 연수구 송도동 24-17
# ...
