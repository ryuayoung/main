# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS

# %% [markdown]
# # Pandas 의 장점
# - Allows the use of labels for rows and columns
# - 기본적인 통계데이터 제공
# - NaN values 를 알아서 처리함.
# - 숫자 문자열을 알아서 로드함.
# - 데이터셋들을 merge 할 수 있음.
# - It integrates with NumPy and Matplotlib

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Series 데이터 생성하기

# %%
index = ['eggs', 'apples', 'milk', 'bread']
data = [30, 6, 'Yes', 'No']

# %%
index
# Out:
# ['eggs', 'apples', 'milk', 'bread']

# %%
index[1]
# Out:
# 'apples'

# %%
pd.Series(data= data)
# Out:
# 0     30
# 1      6
# 2    Yes
# 3     No
# dtype: object

# %%
# 용어 필수 암기

# 판다스의 1차원 데이터를 Series (시리즈) 라고 부른다.

# %%
# 시리즈의 오른쪽 부분을 values (data) 라고 하고
# 시리즈의 왼쪽 부분을 index 라고 한다.

# %%
groceries = pd.Series(data= data, index= index)

# %%
groceries.ndim
# Out:
# 1

# %%
groceries.size
# Out:
# 4

# %%
groceries
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
groceries.shape
# Out:
# (4,)

# %%
(1, 2, 3, 4)
# Out:
# (1, 2, 3, 4)

# %%
(1,)
# Out:
# (1,)

# %%
groceries.index
# Out:
# Index(['eggs', 'apples', 'milk', 'bread'], dtype='object')

# %%
groceries
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
groceries.values
# Out:
# array([30, 6, 'Yes', 'No'], dtype=object)

# %% [markdown]
# ## Accessing and Deleting Elements in Pandas Series - 레이블과 인덱스

# %%
groceries
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
groceries['eggs']
# Out:
# 30

# %%
groceries[   ['eggs','bread']    ]
# Out:
# eggs     30
# bread    No
# dtype: object

# %%
groceries
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
groceries['bread']
# Out:
# 'No'

# %%
groceries[-1]
# Out:
# 'No'

# %%
groceries
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object

# %%
# eggs 부터 milk 까지의 데이터를 가져온다.

#  eggs ~ milk ,    eggs : milk

# %%
groceries[  'eggs' : 'milk'  ]
# Out:
# eggs       30
# apples      6
# milk      Yes
# dtype: object

# %% [markdown]
# ## Arithmetic Operations on Pandas Series

# %%
index = ['apples', 'oranges', 'bananas']
data = [10, 6, 3,]

# %%
fruits = pd.Series(data= data, index= index)

# %%
fruits
# Out:
# apples     10
# oranges     6
# bananas     3
# dtype: int64

# %%
fruit_list = [ 10, 6, 3 ]

# %%
fruit_list
# Out:
# [10, 6, 3]

# %%
new_list = []
for fruit in fruit_list :
  new_list.append(fruit + 5)

# %%
new_list
# Out:
# [15, 11, 8]

# %%
fruits
# Out:
# apples     10
# oranges     6
# bananas     3
# dtype: int64

# %%
fruits = fruits + 5

# %%
fruits
# Out:
# apples     15
# oranges    11
# bananas     8
# dtype: int64

# %%
fruits['oranges'] = fruits['oranges'] - 2

# %%
fruits
# Out:
# apples     15
# oranges     9
# bananas     8
# dtype: int64

# %%
fruits
# Out:
# apples     15
# oranges     9
# bananas     8
# dtype: int64

# %%
fruits[ ['apples', 'bananas'] ] = fruits[  ['apples', 'bananas']   ] - 3

# %%
fruits
# Out:
# apples     12
# oranges     9
# bananas     5
# dtype: int64

# %% [markdown]
# # 실습
# import pandas as pd
#
# ## 1. 다음과 같은 레이블과 값을 가지는 Pandas Series 를 만드세요. 변수는 dist_planets 로 만드세요.
#
# ### distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]
#
# ### planets = ['Earth','Saturn', 'Mars','Venus', 'Jupiter']
#
# ### dist_planets =
#
#
#
# ## 3. 거리를 빛의 상수 c( 18 ) 로 나눠서, 가는 시간이 얼마나 걸리는 지 계산하여 저장하세요.
# ### time_light =
#
# ## 3. Boolean indexing을 이용해서 가는 시간이 40분보다 작은것들만 셀렉트 하세요.
# ### close_planets =

# %%
distance_from_sun = [149.6, 1433.5, 227.9, 108.2, 778.6]

# %%
planets = ['Earth','Saturn', 'Mars','Venus', 'Jupiter']

# %%
dist_planets = pd.Series(data = distance_from_sun, index= planets)

# %%
time_light = dist_planets / 18

# %%
time_light
# Out:
# Earth       8.311111
# Saturn     79.638889
# Mars       12.661111
# Venus       6.011111
# Jupiter    43.255556
# dtype: float64

# %%
time_light < 40
# Out:
# Earth       True
# Saturn     False
# Mars        True
# Venus       True
# Jupiter    False
# dtype: bool

# %%
time_light[ time_light < 40 ]
# Out:
# Earth     8.311111
# Mars     12.661111
# Venus     6.011111
# dtype: float64

# %% [markdown]
# ## Pandas Dataframe

# %% [markdown]
# ### 레이블로 생성하기

# %%
import pandas as pd

# We create a dictionary of Pandas Series
items = {'Bob' : pd.Series(data = [245, 25, 55], index = ['bike', 'pants', 'watch']),
         'Alice' : pd.Series(data = [40, 110, 500, 45], index = ['book', 'glasses', 'bike', 'pants'])}

# %%
df = pd.DataFrame(data = items)

# %%
# 왼쪽 진한 글씨를 index 라고 하고
# 윗쪽 진한 글씨를 comumns 라고 하고
# 안쪽 데이터부분을 values 라고 한다.

# %%
df
# Out:
#            Bob  Alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# watch     55.0    NaN

# %%
df.shape
# Out:
# (5, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 10

# %%
df.index
# Out:
# Index(['bike', 'book', 'glasses', 'pants', 'watch'], dtype='object')

# %%
df.columns
# Out:
# Index(['Bob', 'Alice'], dtype='object')

# %%
df.values
# Out:
# array([[245., 500.],
#        [ nan,  40.],
#        [ nan, 110.],
#        [ 25.,  45.],
#        [ 55.,  nan]])

# %% [markdown]
# ### NaN 은 해당 항목에 값이 없음을 뜻합니다.  (Not a Number)

# %%
# We create a dictionary of Pandas Series without indexes
data = {'Bob' : pd.Series([245, 25, 55]),
        'Alice' : pd.Series([40, 110, 500, 45])}

# %%
df
# Out:
#            Bob  Alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# watch     55.0    NaN

# %% [markdown]
# ### 인덱스 및 컬럼 생성하기

# %%
items = {'Bob' : pd.Series(data = [245, 25, 55], index = ['bike', 'pants', 'watch']),
         'Alice' : pd.Series(data = [40, 110, 500, 45], index = ['book', 'glasses', 'bike', 'pants'])}

# %% [markdown]
# ## Accessing Elements in Pandas DataFrames

# %%
import pandas as pd

# %%
# We create a list of Python dictionaries
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35},
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5}]

# %%
df = pd.DataFrame(data = items2, index= ['store 1', 'store 2'] )

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
#### 판다스의 2차원 데이터를 처리하는 "데이터프레임"에서
#### 데이터를 억세스 하는 방법 3가지.

# 1. 컬럼의 데이터를 가져오는 방법 : 변수명 오른쪽에 대괄호를 사용.

# %%
df['bikes']
# Out:
# store 1    20
# store 2    15
# Name: bikes, dtype: int64

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
df[  ['bikes','watches']  ]
# Out:
#          bikes  watches
# store 1     20       35
# store 2     15       10

# %%
# 2. 사람용인, 인덱스와 컬럼명으로 데이터를 억세스 하는 방법

#    변수명.loc[  ,  ]

# %%
# 스토어1의 데이터를 가져오시오.

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
df.loc[  'store 1' ,  ]
# Out:
# bikes      20.0
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store 1, dtype: float64

# %%
df.loc[ 'store 1'  ,  :  ]
# Out:
# bikes      20.0
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store 1, dtype: float64

# %%
# 스토어 1의 팬츠데이터를 가져오시오.

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
df.loc[ 'store 1' , 'pants' ]
# Out:
# 30

# %%
df['pants']['store 1']
# Out:
# 30

# %%
# 스토어1의 바이크와 와치 데이터를 가져오시오.

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
df.loc[ 'store 1' , ['bikes','watches']  ]
# Out:
# bikes      20.0
# watches    35.0
# Name: store 1, dtype: float64

# %%
# 스토어 2에서, 팬츠부터 글래시스 까지의 데이터를 가져오시오

# %%
df.loc[ 'store 2'  ,  'pants' :   ]
# Out:
# pants       5.0
# watches    10.0
# glasses    50.0
# Name: store 2, dtype: float64

# %%
# 3. 컴퓨터용인, 컴퓨터인덱스로 데이터를 가져오는 방법

#    변수명.iloc[  ,  ]

# %%
# 스토어1의 데이터를 가져오시오.

# %%
df.iloc[ 0 ,  ]
# Out:
# bikes      20.0
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store 1, dtype: float64

# %%
# 스토어1의 팬츠 데이터를 가져오시오.

# %%
df.iloc[  0 ,  1 ]
# Out:
# 30

# %%
# 스토어1의 바이크와 와치의 데이터를 가져오시오.

# %%
df.iloc[ 0  ,  [0, 2]  ]
# Out:
# bikes      20.0
# watches    35.0
# Name: store 1, dtype: float64

# %%
# 스토어1의 데이터중, 팬츠부터 글래시스까지 가져오시오.

# %%
df.iloc[ 0 ,  1 :  ]
# Out:
# pants      30.0
# watches    35.0
# glasses     NaN
# Name: store 1, dtype: float64

# %%
df.iloc[ 0 ,  1 : 2+1 ]
# Out:
# pants      30.0
# watches    35.0
# Name: store 1, dtype: float64

# %%
df.loc[ 'store 1' , 'pants' :  'watches'   ]
# Out:
# pants      30.0
# watches    35.0
# Name: store 1, dtype: float64

# %%
# 데이터의 값 변경

# %%
# 스토어2의 시계 갯수를 20으로 변경하세요.

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
df.loc[ 'store 2' , 'watches' ] = 20

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       20     50.0

# %%
# 새로운 컬럼을 만드는 방법

# %%
# shirts 라는 컬럼을 만들되,  store 1에는 15, store 2 에는 2 로 저장하세요.

# %%
df
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       20     50.0

# %%
df['shirts'] = [15, 2]

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts
# store 1     20     30       35      NaN      15
# store 2     15      5       20     50.0       2

# %%
#  suits 라는 컬럼을 만들되,  pants 의 수와 shirts 의 수를 더해서 만드세요.

# %%
df['pants'] + df['shirts']
# Out:
# store 1    45
# store 2     7
# dtype: int64

# %%
df['suits'] = df['pants'] + df['shirts']

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN      15     45
# store 2     15      5       20     50.0       2      7

# %%
#  행삭제, 열삭제 하는 방법

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN      15     45
# store 2     15      5       20     50.0       2      7

# %%
# store 1을 삭제하는 방법

# %%
df.drop('store 1', axis= 0 )
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 2     15      5       20     50.0       2      7

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN      15     45
# store 2     15      5       20     50.0       2      7

# %%
# watches 컬럼을 삭제하시오.

# %%
df.drop('watches' , axis = 1)
# Out:
#          bikes  pants  glasses  shirts  suits
# store 1     20     30      NaN      15     45
# store 2     15      5     50.0       2      7

# %%
# bikes, glasses, suits 컬럼을 삭제하시오.

# %%
df.drop(  ['bikes','glasses','suits'] , axis = 1 )
# Out:
#          pants  watches  shirts
# store 1     30       35      15
# store 2      5       20       2

# %%
# 인덱스나 컬럼명을 바꾸는 방법

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN      15     45
# store 2     15      5       20     50.0       2      7

# %%
df.rename(index= {'store 2' : 'last store'})
# Out:
#             bikes  pants  watches  glasses  shirts  suits
# store 1        20     30       35      NaN      15     45
# last store     15      5       20     50.0       2      7

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN      15     45
# store 2     15      5       20     50.0       2      7

# %%
df.rename( columns= {'bikes' : 'hats'} )
# Out:
#          hats  pants  watches  glasses  shirts  suits
# store 1    20     30       35      NaN      15     45
# store 2    15      5       20     50.0       2      7

# %%
# 컬럼을 인덱스로 사용하는 방법

# %%
# 가게이름을 A, B 라고 하여, 새로운 컬럼 name 컬럼을 만드세요.

# %%
df['name'] = [ 'A' , 'B']

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits name
# store 1     20     30       35      NaN      15     45    A
# store 2     15      5       20     50.0       2      7    B

# %%
df.set_index( 'name' )
# Out:
#       bikes  pants  watches  glasses  shirts  suits
# name
# A        20     30       35      NaN      15     45
# B        15      5       20     50.0       2      7

# %%
df
# Out:
#          bikes  pants  watches  glasses  shirts  suits name
# store 1     20     30       35      NaN      15     45    A
# store 2     15      5       20     50.0       2      7    B

# %%
df = df.set_index( 'name' )

# %%
df
# Out:
#       bikes  pants  watches  glasses  shirts  suits
# name
# A        20     30       35      NaN      15     45
# B        15      5       20     50.0       2      7

# %%
df.reset_index()
# Out:
#   name  bikes  pants  watches  glasses  shirts  suits
# 0    A     20     30       35      NaN      15     45
# 1    B     15      5       20     50.0       2      7

# %%
df
# Out:
#       bikes  pants  watches  glasses  shirts  suits
# name
# A        20     30       35      NaN      15     45
# B        15      5       20     50.0       2      7

# %%
df = df[ ['watches', 'shirts', 'bikes', 'pants', 'suits', 'glasses']  ]

# %%
df
# Out:
#       watches  shirts  bikes  pants  suits  glasses
# name
# A          35      15     20     30     45      NaN
# B          20       2     15      5      7     50.0

# %% [markdown]
# ## Dealing with NaN

# %%
# We create a list of Python dictionaries
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35, 'shirts': 15, 'shoes':8, 'suits':45},
{'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5, 'shirts': 2, 'shoes':5, 'suits':7},
{'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4, 'shoes':10}]

# %%
df = pd.DataFrame(data= items2, index = ['store 1', 'store 2', 'store 3'])

# %%
df
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
df.shape
# Out:
# (3, 7)

# %%
# NaN 을 파악하는 방법

# %%
df.isna().sum()
# Out:
# bikes      0
# pants      0
# watches    0
# shirts     1
# shoes      0
# suits      1
# glasses    1
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 3

# %%
# BNd

# %%
# Nan을 처리하는 방법

# %%
# 1. 삭제하는 방법

# %%
df.dropna()
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 2     15      5       10     2.0      5    7.0     50.0

# %%
# 2. 특정 값으로 채우는 방법

# %%
df
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
df.fillna(0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      0.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10    0.0      4.0

# %%
df.fillna('데이터없음')
# Out:
#          bikes  pants  watches shirts  shoes  suits glasses
# store 1     20     30       35   15.0      8   45.0   데이터없음
# store 2     15      5       10    2.0      5    7.0    50.0
# store 3     20     30       35  데이터없음     10  데이터없음     4.0

# %%
df
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
# 셔츠가 NaN인 값만, No Data 로 채우세요.

# %%
df['shirts'].fillna('No Data')
# Out:
# store 1       15.0
# store 2        2.0
# store 3    No Data
# Name: shirts, dtype: object

# %%
df['shirts'] = df['shirts'].fillna('No Data')

# %%
df
# Out:
#          bikes  pants  watches   shirts  shoes  suits  glasses
# store 1     20     30       35     15.0      8   45.0      NaN
# store 2     15      5       10      2.0      5    7.0     50.0
# store 3     20     30       35  No Data     10    NaN      4.0

# %%
# 채우긴 채우되, 앞이나 뒤의 데이터를 사용해서 채우는 방법

# %%
df.fillna(method= 'ffill' , axis = 0 )
# Out:
#          bikes  pants  watches   shirts  shoes  suits  glasses
# store 1     20     30       35     15.0      8   45.0      NaN
# store 2     15      5       10      2.0      5    7.0     50.0
# store 3     20     30       35  No Data     10    7.0      4.0

# %%
df.fillna(method= 'bfill' , axis = 0 )
# Out:
#          bikes  pants  watches   shirts  shoes  suits  glasses
# store 1     20     30       35     15.0      8   45.0     50.0
# store 2     15      5       10      2.0      5    7.0     50.0
# store 3     20     30       35  No Data     10    NaN      4.0

# %%
df.fillna(method= 'ffill' , axis = 1 )
# Out:
#         bikes pants watches   shirts shoes suits glasses
# store 1  20.0  30.0    35.0     15.0   8.0  45.0    45.0
# store 2  15.0   5.0    10.0      2.0   5.0   7.0    50.0
# store 3    20    30      35  No Data    10    10     4.0

# %%
df.fillna(method= 'bfill' , axis = 1 )
# Out:
#         bikes pants watches   shirts shoes suits glasses
# store 1  20.0  30.0    35.0     15.0   8.0  45.0     NaN
# store 2  15.0   5.0    10.0      2.0   5.0   7.0    50.0
# store 3    20    30      35  No Data    10   4.0     4.0

# %%
#  채우는 방법중에서, 각 컬럼별 평균값으로 채우기.
#  최소값으로 채우기, 최대값으로 채우기  가 가능하다.

# %%
df
# Out:
#          bikes  pants  watches   shirts  shoes  suits  glasses
# store 1     20     30       35     15.0      8   45.0      NaN
# store 2     15      5       10      2.0      5    7.0     50.0
# store 3     20     30       35  No Data     10    NaN      4.0

# %%
df.loc['store 3' , 'shirts' ]
# Out:
# 'No Data'

# %%
df.loc['store 3' , 'shirts' ] = 0

# %%
df
# Out:
#          bikes  pants  watches shirts  shoes  suits  glasses
# store 1     20     30       35   15.0      8   45.0      NaN
# store 2     15      5       10    2.0      5    7.0     50.0
# store 3     20     30       35      0     10    NaN      4.0

# %%
df.mean()
# Out:
# bikes      18.333333
# pants      21.666667
# watches    26.666667
# shirts      5.666667
# shoes       7.666667
# suits      26.000000
# glasses    27.000000
# dtype: float64

# %%
df.fillna( df.mean() )
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0     27.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10   26.0      4.0

# %%
df.fillna( df.max() )
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0     50.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10   45.0      4.0

# %%
df.fillna( df.min() )
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      4.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10    7.0      4.0

# %%
df.notna()
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   True   True     True    True   True   True    False
# store 2   True   True     True    True   True   True     True
# store 3   True   True     True    True   True  False     True

# %% [markdown]
# # 실습

# %%
import pandas as pd
import numpy as np

# 책 제목과 작가, 그리고 유저별 별점 데이터가 있다.

books = pd.Series(data = ['Great Expectations', 'Of Mice and Men', 'Romeo and Juliet', 'The Time Machine', 'Alice in Wonderland' ])
authors = pd.Series(data = ['Charles Dickens', 'John Steinbeck', 'William Shakespeare', ' H. G. Wells', 'Lewis Carroll' ])

user_1 = pd.Series(data = [3.2, np.nan ,2.5])
user_2 = pd.Series(data = [5., 1.3, 4.0, 3.8])
user_3 = pd.Series(data = [2.0, 2.3, np.nan, 4])
user_4 = pd.Series(data = [4, 3.5, 4, 5, 4.2])

#  np.nan values 는 해당 유저가 해당 책에는 아직 별점 주지 않은것이다.
# labels: 'Author', 'Book Title', 'User 1', 'User 2', 'User 3', 'User 4'.
# 아래 그림처럼 나오도록 만든다.

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-27%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.28.49.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-27%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%206.28.49.png)

# %%
# 1. 딕셔너리를 만들고,    2. 데이터프레임으로 만든 후,    3. nan을  평균값으로 채운다.

# %%
books
# Out:
# 0     Great Expectations
# 1        Of Mice and Men
# 2       Romeo and Juliet
# 3       The Time Machine
# 4    Alice in Wonderland
# dtype: object

# %%
authors
# Out:
# 0        Charles Dickens
# 1         John Steinbeck
# 2    William Shakespeare
# 3            H. G. Wells
# 4          Lewis Carroll
# dtype: object

# %%
my_data = { 'Book Title' : books, 'Authors' : authors, 'User1' : user_1,
  'User2' : user_2, 'User3' : user_3, 'User_4' : user_4}

# %%
my_data
# Out:
# {'Book Title': 0     Great Expectations
#  1        Of Mice and Men
#  2       Romeo and Juliet
#  3       The Time Machine
#  4    Alice in Wonderland
#  dtype: object,
#  'Authors': 0        Charles Dickens
#  1         John Steinbeck
#  2    William Shakespeare
#  3            H. G. Wells
#  4          Lewis Carroll
#  dtype: object,
#  'User1': 0    3.2
#  1    NaN
#  2    2.5
#  dtype: float64,
#  'User2': 0    5.0
#  1    1.3
#  2    4.0
#  3    3.8
#  dtype: float64,
#  'User3': 0    2.0
#  1    2.3
#  2    NaN
#  3    4.0
#  dtype: float64,
#  'User_4': 0    4.0
#  1    3.5
#  2    4.0
#  3    5.0
#  4    4.2
#  dtype: float64}

# %%
df = pd.DataFrame(data= my_data)

# %%
df
# Out:
#             Book Title              Authors  User1  User2  User3  User_4
# 0   Great Expectations      Charles Dickens    3.2    5.0    2.0     4.0
# 1      Of Mice and Men       John Steinbeck    NaN    1.3    2.3     3.5
# 2     Romeo and Juliet  William Shakespeare    2.5    4.0    NaN     4.0
# 3     The Time Machine          H. G. Wells    NaN    3.8    4.0     5.0
# 4  Alice in Wonderland        Lewis Carroll    NaN    NaN    NaN     4.2

# %%
df.mean( numeric_only= True )
# Out:
# User1     2.850000
# User2     3.525000
# User3     2.766667
# User_4    4.140000
# dtype: float64

# %%
df.fillna( df.mean( numeric_only= True )  )
# Out:
#             Book Title              Authors  User1  User2     User3  User_4
# 0   Great Expectations      Charles Dickens   3.20  5.000  2.000000     4.0
# 1      Of Mice and Men       John Steinbeck   2.85  1.300  2.300000     3.5
# 2     Romeo and Juliet  William Shakespeare   2.50  4.000  2.766667     4.0
# 3     The Time Machine          H. G. Wells   2.85  3.800  4.000000     5.0
# 4  Alice in Wonderland        Lewis Carroll   2.85  3.525  2.766667     4.2

# %% [markdown]
# ## Loading Data into a Pandas DataFrame

# %%
# CSV (Comma Separated Values) 파일을 읽는 방법

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/데이터분석/data/GOOG.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19   49.676899   51.693783   47.669952   49.845802   49.845802
# 1     2004-08-20   50.178635   54.187561   49.925285   53.805050   53.805050
# 2     2004-08-23   55.017166   56.373344   54.172661   54.346527   54.346527
# 3     2004-08-24   55.260582   55.439419   51.450363   52.096165   52.096165
# 4     2004-08-25   52.140873   53.651051   51.604362   52.657513   52.657513
# ...          ...         ...         ...         ...         ...         ...
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#         Volume
# 0     44994500
# ...

# %%
df.shape
# Out:
# (3313, 7)

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# 기본적인 통계 데이터를 보여주는 함수

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3313.000000  3313.000000  3313.000000  3313.000000  3313.000000
# mean    380.186092   383.493740   376.519309   380.072458   380.072458
# std     223.818650   224.974534   222.473232   223.853780   223.853780
# min      49.274517    50.541279    47.669952    49.681866    49.681866
# 25%     226.556473   228.394516   224.003082   226.407440   226.407440
# 50%     293.312286   295.433502   289.929291   293.029114   293.029114
# 75%     536.650024   540.000000   532.409973   536.690002   536.690002
# max     992.000000   997.210022   989.000000   989.679993   989.679993
#
#              Volume
# count  3.313000e+03
# mean   8.038476e+06
# std    8.399521e+06
# min    7.900000e+03
# 25%    2.584900e+06
# 50%    5.281300e+06
# 75%    1.065370e+07
# max    8.276810e+07

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500
# 1  2004-08-20  50.178635  54.187561  49.925285  53.805050  53.805050  23005800
# 2  2004-08-23  55.017166  56.373344  54.172661  54.346527  54.346527  18393200
# 3  2004-08-24  55.260582  55.439419  51.450363  52.096165  52.096165  15361800
# 4  2004-08-25  52.140873  53.651051  51.604362  52.657513  52.657513   9257400

# %%
df.head(1)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.676899  51.693783  47.669952  49.845802  49.845802  44994500

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3308  2017-10-09  980.000000  985.424988  976.109985  977.000000  977.000000
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#        Volume
# 3308   891400
# 3309   968400
# 3310  1693300
# 3311  1262400
# 3312  1157700

# %%
df.tail(4)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3309  2017-10-10  980.000000  981.570007  966.080017  972.599976  972.599976
# 3310  2017-10-11  973.719971  990.710022  972.250000  989.250000  989.250000
# 3311  2017-10-12  987.450012  994.119995  985.000000  987.830017  987.830017
# 3312  2017-10-13  992.000000  997.210022  989.000000  989.679993  989.679993
#
#        Volume
# 3309   968400
# 3310  1693300
# 3311  1262400
# 3312  1157700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3313 non-null   object
#  1   Open       3313 non-null   float64
#  2   High       3313 non-null   float64
#  3   Low        3313 non-null   float64
#  4   Close      3313 non-null   float64
#  5   Adj Close  3313 non-null   float64
#  6   Volume     3313 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 181.3+ KB

# %%
# 상한가의 기초통계 정보를 보여주세요.

# %%
df['High'].describe()
# Out:
# count    3313.000000
# mean      383.493740
# std       224.974534
# min        50.541279
# 25%       228.394516
# 50%       295.433502
# 75%       540.000000
# max       997.210022
# Name: High, dtype: float64

# %%
# 시작가와 종가에 대한 기초통계 데이터를 보여주세요.

# %%
df[ ['Open', 'Close'] ].describe()
# Out:
#               Open        Close
# count  3313.000000  3313.000000
# mean    380.186092   380.072458
# std     223.818650   223.853780
# min      49.274517    49.681866
# 25%     226.556473   226.407440
# 50%     293.312286   293.029114
# 75%     536.650024   536.690002
# max     992.000000   989.679993

# %%
# 상한가의 최대값은??

# %%
df['High'].max()
# Out:
# 997.210022

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/데이터분석/data/fake_company.csv')

# %%
df
# Out:
#    Year     Name Department  Age  Salary
# 0  1990    Alice         HR   25   50000
# 1  1990      Bob         RD   30   48000
# 2  1990  Charlie      Admin   45   55000
# 3  1991    Alice         HR   26   52000
# 4  1991      Bob         RD   31   50000
# 5  1991  Charlie      Admin   46   60000
# 6  1992    Alice         HR   27   60000
# 7  1992      Bob         RD   32   52000
# 8  1992  Charlie      Admin   47   62000

# %%
# 중복된 데이터를 가지고 있는 컬럼들이 있다.

# 예를 들면, 성별과 같은 컬럼들이다.

# 이런 데이터를, 카테고리컬 데이터라고 한다.

# %%
df
# Out:
#    Year     Name Department  Age  Salary
# 0  1990    Alice         HR   25   50000
# 1  1990      Bob         RD   30   48000
# 2  1990  Charlie      Admin   45   55000
# 3  1991    Alice         HR   26   52000
# 4  1991      Bob         RD   31   50000
# 5  1991  Charlie      Admin   46   60000
# 6  1992    Alice         HR   27   60000
# 7  1992      Bob         RD   32   52000
# 8  1992  Charlie      Admin   47   62000

# %%
# 중복제거한 유니크한 데이터의 갯수를 세는 방법

df['Year'].nunique()
# Out:
# 3

# %%
# 데이터의 전체 갯수를 세는 방법
df['Year'].count()
# Out:
# 9

# %%
# 중복제거한 유니크한 데이터를 표시
df['Year'].unique()
# Out:
# array([1990, 1991, 1992])

# %%
# 데이터프레임전체에 describe 를 하면, 수치데이터만 보여준다.

df.describe()
# Out:
#               Year        Age        Salary
# count     9.000000   9.000000      9.000000
# mean   1991.000000  34.333333  54333.333333
# std       0.866025   9.055385   5147.815070
# min    1990.000000  25.000000  48000.000000
# 25%    1990.000000  27.000000  50000.000000
# 50%    1991.000000  31.000000  52000.000000
# 75%    1992.000000  45.000000  60000.000000
# max    1992.000000  47.000000  62000.000000

# %%
# describe 함수를,  문자열데이터 컬럼 하나에만 적용하면,
# 빈도수 등을 알수 있다.

# %%
df['Name'].describe()
# Out:
# count         9
# unique        3
# top       Alice
# freq          3
# Name: Name, dtype: object

# %%
# 카테고리컬 데이터의 각 데이터별로, 묶어서 처리하는 방법

# %%
# 각 년도별로, 연봉 총합을 구하시오.

# %%
df.groupby('Year')['Salary'].sum()
# Out:
# Year
# 1990    153000
# 1991    162000
# 1992    174000
# Name: Salary, dtype: int64

# %%
# 각 직원별로, 해당 직원이 받은 연봉 평균은 얼마인가?

# %%
df.groupby('Name')['Salary'].mean()
# Out:
# Name
# Alice      54000.0
# Bob        50000.0
# Charlie    59000.0
# Name: Salary, dtype: float64

# %%
# 년도별과 부서별로 연봉은 총 얼마씩 지급되었는가?

# %%
df.groupby( ['Year','Department']  )['Salary'].sum()
# Out:
# Year  Department
# 1990  Admin         55000
#       HR            50000
#       RD            48000
# 1991  Admin         60000
#       HR            52000
#       RD            50000
# 1992  Admin         62000
#       HR            60000
#       RD            52000
# Name: Salary, dtype: int64

# %%
# 년도별 연봉의 총합과 최소값, 평균값을 구하세요.

# %%
df.groupby('Year')['Salary'].agg( [np.sum,  np.min, np.mean] )
# Out:
#          sum   amin     mean
# Year
# 1990  153000  48000  51000.0
# 1991  162000  50000  54000.0
# 1992  174000  52000  58000.0

# %%
# Name 컬럼의 사람이름은 각각 몇개씩 있는지 파악하시오.

# 직원의 이름별로, 이름에 해당되는 데이터는 몇개씩 있는가?

# %%
df.groupby('Name')['Name'].count()
# Out:
# Name
# Alice      3
# Bob        3
# Charlie    3
# Name: Name, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Alice      3
# Bob        3
# Charlie    3
# Name: Name, dtype: int64

# %% [markdown]
# # GETTING HTML DATA

# %%
df = pd.read_html('https://www.livingin-canada.com/house-prices-canada.html')

# %%
a = [1,5,4,6]

# %%
len(a)
# Out:
# 4

# %%
len(df)
# Out:
# 2

# %%
df[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# ...

# %%
df[0].loc[ 0 :  7  ,   ]
# Out:
#               City Average House Price 12 Month Change
# 0    Vancouver, BC          $1,036,000        + 2.63 %
# 1     Toronto, Ont            $870,000         +10.2 %
# 2      Ottawa, Ont            $479,000        + 15.4 %
# 3     Calgary, Alb            $410,000         – 1.5 %
# 4    Montreal, Que            $435,000         + 9.3 %
# 5      Halifax, NS            $331,000         + 3.6 %
# 6     Regina, Sask            $254,000         – 3.9 %
# 7  Fredericton, NB            $198,000         – 4.3 %

# %%
city = df[0].drop( 8 , axis = 0 )

# %%
city
# Out:
#               City Average House Price 12 Month Change
# 0    Vancouver, BC          $1,036,000        + 2.63 %
# 1     Toronto, Ont            $870,000         +10.2 %
# 2      Ottawa, Ont            $479,000        + 15.4 %
# 3     Calgary, Alb            $410,000         – 1.5 %
# 4    Montreal, Que            $435,000         + 9.3 %
# 5      Halifax, NS            $331,000         + 3.6 %
# 6     Regina, Sask            $254,000         – 3.9 %
# 7  Fredericton, NB            $198,000         – 4.3 %

# %%
province = df[1].drop(11, axis = 0)

# %%
city
# Out:
#               City Average House Price 12 Month Change
# 0    Vancouver, BC          $1,036,000        + 2.63 %
# 1     Toronto, Ont            $870,000         +10.2 %
# 2      Ottawa, Ont            $479,000        + 15.4 %
# 3     Calgary, Alb            $410,000         – 1.5 %
# 4    Montreal, Que            $435,000         + 9.3 %
# 5      Halifax, NS            $331,000         + 3.6 %
# 6     Regina, Sask            $254,000         – 3.9 %
# 7  Fredericton, NB            $198,000         – 4.3 %

# %%
# Average House Price 의 평균을 구하세요

# %%
city['Average House Price'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1629         try:
# -> 1630             x = float(x)
#    1631         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '$1,036,000$870,000$479,000$410,000$435,000$331,000$254,000$198,000'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1633             try:
# -> 1634                 x = complex(x)
#    1635             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
city['price']  = city['Average House Price'].str.replace('$', '').str.replace(',', '').astype(int)
# Out:
# <ipython-input-122-92b9ece9223b>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   city['price']  = city['Average House Price'].str.replace('$', '').str.replace(',', '').astype(int)

# %%
city
# Out:
#               City Average House Price 12 Month Change    price
# 0    Vancouver, BC          $1,036,000        + 2.63 %  1036000
# 1     Toronto, Ont            $870,000         +10.2 %   870000
# 2      Ottawa, Ont            $479,000        + 15.4 %   479000
# 3     Calgary, Alb            $410,000         – 1.5 %   410000
# 4    Montreal, Que            $435,000         + 9.3 %   435000
# 5      Halifax, NS            $331,000         + 3.6 %   331000
# 6     Regina, Sask            $254,000         – 3.9 %   254000
# 7  Fredericton, NB            $198,000         – 4.3 %   198000

# %%
city['price'].mean()
# Out:
# 501625.0

# %%
price = '$435,000'

# %%
price = int(  price.replace('$', '').replace(',', '')  )

# %%
price
# Out:
# 435000

# %%
price + 3000
# Out:
# 438000

# %% [markdown]
# # PANDAS OPERATIONS

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Employee ID':[111, 222, 333, 444],
                   'Employee Name':['Chanel', 'Steve', 'Mitch', 'Bird'],
                   'Salary [$/h]':[35, 29, 38, 20],
                   'Years of Experience':[3, 4 ,9, 1]})
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 1          222         Steve            29                    4
# 2          333         Mitch            38                    9
# 3          444          Bird            20                    1

# %%
# 경력이 3년 이상인 사람의 데이터를 가져오시오.

# %%
df['Years of Experience'] >= 3
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: Years of Experience, dtype: bool

# %%
df.loc[  df['Years of Experience'] >= 3  ,   ]
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 1          222         Steve            29                    4
# 2          333         Mitch            38                    9

# %%
# 이 방법은 안된다.
df.iloc[ df['Years of Experience'] >= 3 ,   ]

# %%
# 경력이 3년 이상인 사람의 이름과 시급을 가져오시오.

# %%
df['Years of Experience'] >= 3
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: Years of Experience, dtype: bool

# %%
df.loc[ df['Years of Experience'] >= 3 ,   ['Employee Name','Salary [$/h]'] ]
# Out:
#   Employee Name  Salary [$/h]
# 0        Chanel            35
# 1         Steve            29
# 2         Mitch            38

# %%
# 경력이 3년 이하이거나 8년 이상인 사람의 이름을 가져오시오.

# %%
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 1          222         Steve            29                    4
# 2          333         Mitch            38                    9
# 3          444          Bird            20                    1

# %%
# 데이터 억세스의 부등식을 조합할때는
# 그리고에 해당하는 &  와
# 또는에 해당하는 | 를 사용한다.

# %%
my_filter = (df['Years of Experience'] <= 3)  |  (df['Years of Experience'] >= 8)

# %%
df.loc[ my_filter ,  ]
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 2          333         Mitch            38                    9
# 3          444          Bird            20                    1

# %%
# 경력이 3년 이상이고, 시급이 30달러 이상인 사람의 데이터를 가져오시오.

# %%
( df['Years of Experience'] >= 3 )  &  (df['Salary [$/h]'] >= 30)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df.loc[( df['Years of Experience'] >= 3 )  &  (df['Salary [$/h]'] >= 30) , ]
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 2          333         Mitch            38                    9

# %%
# 시급이 가장 높은 사람의 이름과 시급을 가져오시오.

# %%
df['Salary [$/h]'].max()
# Out:
# 38

# %%
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 1          222         Steve            29                    4
# 2          333         Mitch            38                    9
# 3          444          Bird            20                    1

# %%
df['Salary [$/h]'] == df['Salary [$/h]'].max()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: Salary [$/h], dtype: bool

# %%
df.loc[ df['Salary [$/h]'] == df['Salary [$/h]'].max() , 'Employee Name':'Salary [$/h]'   ]
# Out:
#   Employee Name  Salary [$/h]
# 2         Mitch            38

# %% [markdown]
# # APPLYING FUNCTIONS

# %%
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 1          222         Steve            29                    4
# 2          333         Mitch            38                    9
# 3          444          Bird            20                    1

# %%
# 직원 이름이 몇글자인지 글자수를 세어서,
# 새로운 컬럼 length 를 만드세요.

# %%
df['length'] = df['Employee Name'].str.len()

# %%
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length
# 0          111        Chanel            35                    3       6
# 1          222         Steve            29                    4       5
# 2          333         Mitch            38                    9       5
# 3          444          Bird            20                    1       4

# %%
# 시급이 30 이상이면, 'A' 그룹이라 하고,
# 시급이 30 보다 작으면, 'B' 그룹이라고 하곘다.
# 새로운 컬럼 group 을 만들어서 저장하세요.

# %%
df['Salary [$/h]']
# Out:
# 0    35
# 1    29
# 2    38
# 3    20
# Name: Salary [$/h], dtype: int64

# %%
# 함수를 만드는 순서!!!

# 1. 함수의 호출부분을 먼저 작성한다.

# 2. 호출부분을 참고하여 함수를 정의한다.

# %%
def grouping(salary):
  if salary >= 30 :
    return 'A'
  else :
    return 'B'

# %%
grouping(35)

# 'A'
# Out:
# 'A'

# %%
grouping(29)

# 'B'
# Out:
# 'B'

# %%
grouping(38)

# 'A'
# Out:
# 'A'

# %%
df['Salary [$/h]'].apply( grouping )
# Out:
# 0    A
# 1    B
# 2    A
# 3    B
# Name: Salary [$/h], dtype: object

# %%
df['group'] = df['Salary [$/h]'].apply( grouping )

# %%
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length group
# 0          111        Chanel            35                    3       6     A
# 1          222         Steve            29                    4       5     B
# 2          333         Mitch            38                    9       5     A
# 3          444          Bird            20                    1       4     B

# %% [markdown]
# # SORTING AND ORDERING

# %%
df = pd.DataFrame({'Employee ID':[111, 222, 333, 444],
                   'Employee Name':['Chanel', 'Steve', 'Mitch', 'Bird'],
                   'Salary [$/h]':[35, 29, 38, 20],
                   'Years of Experience':[3, 4 ,9, 1]})
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience
# 0          111        Chanel            35                    3
# 1          222         Steve            29                    4
# 2          333         Mitch            38                    9
# 3          444          Bird            20                    1

# %%
df
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length group
# 0          111        Chanel            35                    3       6     A
# 1          222         Steve            29                    4       5     B
# 2          333         Mitch            38                    9       5     A
# 3          444          Bird            20                    1       4     B

# %%
# 경력 오름차순으로 정렬하세요

# %%
df['Years of Experience'].sort_values()
# Out:
# 3    1
# 0    3
# 1    4
# 2    9
# Name: Years of Experience, dtype: int64

# %%
df.sort_values('Years of Experience')
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length group
# 3          444          Bird            20                    1       4     B
# 0          111        Chanel            35                    3       6     A
# 1          222         Steve            29                    4       5     B
# 2          333         Mitch            38                    9       5     A

# %%
# 경력을 내림차순으로 정렬하세요

# %%
df.sort_values('Years of Experience', ascending= False)
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length group
# 2          333         Mitch            38                    9       5     A
# 1          222         Steve            29                    4       5     B
# 0          111        Chanel            35                    3       6     A
# 3          444          Bird            20                    1       4     B

# %%
# length 컬럼을 내림차순으로 정렬하세요

# %%
df.sort_values('length', ascending= False)
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length group
# 0          111        Chanel            35                    3       6     A
# 1          222         Steve            29                    4       5     B
# 2          333         Mitch            38                    9       5     A
# 3          444          Bird            20                    1       4     B

# %%
# 정렬 조건이 2개 이상일 경우의 정렬 방법

# %%
# length 를 내림차순으로 정렬하되, 숫자가 같으면, 이름을 오름차순으로 정렬하세요

# %%
df.sort_values( ['length' , 'Employee Name'] , ascending= [False, True ]  )
# Out:
#    Employee ID Employee Name  Salary [$/h]  Years of Experience  length group
# 0          111        Chanel            35                    3       6     A
# 2          333         Mitch            38                    9       5     A
# 1          222         Steve            29                    4       5     B
# 3          444          Bird            20                    1       4     B

# %% [markdown]
# # CONCATENATING AND MERGING

# %% [markdown]
# ![image.png](attachment:image.png)
# Reference: https://pandas.pydata.org/pandas-docs/stable/merging.html

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
index=[0, 1, 2, 3])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
index=[4, 5, 6, 7])

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
index=[8, 9, 10, 11])

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# 여러 데이터 프레임의 컬럼명이 같으면,
# 하나의 데이터 프레임으로 합칠 수 있다.

# %%
pd.concat(  [df1, df2, df3]   )
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat( [df3, df1, df2] )
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7

# %%
# Creating a dataframe from a dictionary
raw_data = {
        'Employee ID': ['1', '2', '3', '4', '5'],
        'first name': ['Diana', 'Cynthia', 'Shep', 'Ryan', 'Allen'],
        'last name': ['Bouchard', 'Ali', 'Rob', 'Mitch', 'Steve']}
df_Engineering_dept = pd.DataFrame(raw_data, columns = ['Employee ID', 'first name', 'last name'])
df_Engineering_dept
# Out:
#   Employee ID first name last name
# 0           1      Diana  Bouchard
# 1           2    Cynthia       Ali
# 2           3       Shep       Rob
# 3           4       Ryan     Mitch
# 4           5      Allen     Steve

# %%
raw_data = {
        'Employee ID': ['6', '7', '8', '9', '10'],
        'first name': ['Bill', 'Dina', 'Sarah', 'Heather', 'Holly'],
        'last name': ['Christian', 'Mo', 'Steve', 'Bob', 'Michelle']}
df_Finance_dept = pd.DataFrame(raw_data, columns = ['Employee ID', 'first name', 'last name'])
df_Finance_dept
# Out:
#   Employee ID first name  last name
# 0           6       Bill  Christian
# 1           7       Dina         Mo
# 2           8      Sarah      Steve
# 3           9    Heather        Bob
# 4          10      Holly   Michelle

# %%
raw_data = {
        'Employee ID': ['1', '2', '3', '4', '5', '7', '8', '9', '10'],
        'Salary [$/hour]': [25, 35, 45, 48, 49, 32, 33, 34, 23]}
df_salary = pd.DataFrame(raw_data, columns = ['Employee ID','Salary [$/hour]'])
df_salary
# Out:
#   Employee ID  Salary [$/hour]
# 0           1               25
# 1           2               35
# 2           3               45
# 3           4               48
# 4           5               49
# 5           7               32
# 6           8               33
# 7           9               34
# 8          10               23

# %%
df_all = pd.concat( [ df_Engineering_dept , df_Finance_dept ] )

# %%
df_all
# Out:
#   Employee ID first name  last name
# 0           1      Diana   Bouchard
# 1           2    Cynthia        Ali
# 2           3       Shep        Rob
# 3           4       Ryan      Mitch
# 4           5      Allen      Steve
# 0           6       Bill  Christian
# 1           7       Dina         Mo
# 2           8      Sarah      Steve
# 3           9    Heather        Bob
# 4          10      Holly   Michelle

# %%
df_salary
# Out:
#   Employee ID  Salary [$/hour]
# 0           1               25
# 1           2               35
# 2           3               45
# 3           4               48
# 4           5               49
# 5           7               32
# 6           8               33
# 7           9               34
# 8          10               23

# %%
# 공통되는 컬럼을 기준으로 합치는 방법

# %%
# merge 함수는, 딱 2개의 데이터프레임만 합치는 함수다.
pd.merge(df_all , df_salary, on= 'Employee ID')
# Out:
#   Employee ID first name last name  Salary [$/hour]
# 0           1      Diana  Bouchard               25
# 1           2    Cynthia       Ali               35
# 2           3       Shep       Rob               45
# 3           4       Ryan     Mitch               48
# 4           5      Allen     Steve               49
# 5           7       Dina        Mo               32
# 6           8      Sarah     Steve               33
# 7           9    Heather       Bob               34
# 8          10      Holly  Michelle               23

# %%
# 모든 직원정보를 다 보여주되, 시급정보가 없으면, 없다고 표시하게 해달라.

# %%
pd.merge(df_all, df_salary, on = 'Employee ID' , how='left' )
# Out:
#   Employee ID first name  last name  Salary [$/hour]
# 0           1      Diana   Bouchard             25.0
# 1           2    Cynthia        Ali             35.0
# 2           3       Shep        Rob             45.0
# 3           4       Ryan      Mitch             48.0
# 4           5      Allen      Steve             49.0
# 5           6       Bill  Christian              NaN
# 6           7       Dina         Mo             32.0
# 7           8      Sarah      Steve             33.0
# 8           9    Heather        Bob             34.0
# 9          10      Holly   Michelle             23.0

# %%
pd.merge(df_all, df_salary, on = 'Employee ID' , how='right' )
# Out:
#   Employee ID first name last name  Salary [$/hour]
# 0           1      Diana  Bouchard               25
# 1           2    Cynthia       Ali               35
# 2           3       Shep       Rob               45
# 3           4       Ryan     Mitch               48
# 4           5      Allen     Steve               49
# 5           7       Dina        Mo               32
# 6           8      Sarah     Steve               33
# 7           9    Heather       Bob               34
# 8          10      Holly  Michelle               23

# %% [markdown]
# # EXCELLENT JOB!
